# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresLAraque/SIENES/blob/main/An%C3%A1lisis_Matriculados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ydata-profiling
# !pip install plotly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.9/357.9 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 7.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 15.9 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=89506ef06d54154ce74e8dd9a1da96b5321ba7f0c713370c0361e6a980b07ccc
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.1
#     Uninstalling seaborn-0.13.1:
# ...

# %%
import pandas as pd
import ydata_profiling
import plotly.express as px

# %%
data= pd.read_csv('/content/drive/MyDrive/SNIES/EstudiantesMatriculados2022.csv')
data.iloc[:, 12:]
# Out:
#        CÓDIGO SNIES DEL PROGRAMA            PROGRAMA ACADÉMICO  \
# 0                              1         INGENIERIA AGRONOMICA
# 1                              1         INGENIERIA AGRONOMICA
# 2                              1         INGENIERIA AGRONOMICA
# 3                              1         INGENIERIA AGRONOMICA
# 4                              2          MEDICINA VETERINARIA
# ...                          ...                           ...
# 49948                     109846  COMUNICACIÓN SOCIAL Y MEDIOS
# 49949                     110347                       DERECHO
# 49950                     110347                       DERECHO
# 49951                     110347                       DERECHO
# 49952                     110347                       DERECHO
#
#        ID NIVEL ACADÉMICO NIVEL ACADÉMICO  ID NIVEL DE FORMACIÓN  \
# 0                       1        PREGRADO                      6
# 1                       1        PREGRADO                      6
# ...

# %%
data.dtypes
# Out:
# CÓDIGO DE LA INSTITUCIÓN                     int64
# IES_PADRE                                    int64
# INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)     object
# PRINCIPAL O SECCIONAL                       object
# ID SECTOR IES                                int64
# SECTOR IES                                  object
# ID CARACTER                                  int64
# CARACTER IES                                object
# CÓDIGO DEL DEPARTAMENTO (IES)                int64
# DEPARTAMENTO DE DOMICILIO DE LA IES         object
# CÓDIGO DEL MUNICIPIO IES                     int64
# MUNICIPIO DE DOMICILIO DE LA IES            object
# CÓDIGO SNIES DEL PROGRAMA                    int64
# PROGRAMA ACADÉMICO                          object
# ID NIVEL ACADÉMICO                           int64
# NIVEL ACADÉMICO                             object
# ID NIVEL DE FORMACIÓN                        int64
# NIVEL DE FORMACIÓN                          object
# ...

# %%
categorias_sector_ies = data['INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)'].unique()
#categorias_sector_ies = data['INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)'].value_counts()
categorias_sector_ies
# Out:
# array(['UNIVERSIDAD NACIONAL DE COLOMBIA',
#        'UNIVERSIDAD PEDAGOGICA NACIONAL',
#        'UNIVERSIDAD PEDAGOGICA Y TECNOLOGICA DE COLOMBIA - UPTC',
#        'UNIVERSIDAD DEL CAUCA',
#        'UNIVERSIDAD TECNOLOGICA DE PEREIRA - UTP',
#        'UNIVERSIDAD DE CALDAS', 'UNIVERSIDAD DE CORDOBA',
#        'UNIVERSIDAD SURCOLOMBIANA', 'UNIVERSIDAD DE LA AMAZONIA',
#        'UNIVERSIDAD MILITAR-NUEVA GRANADA',
#        'UNIVERSIDAD TECNOLOGICA DEL CHOCO-DIEGO LUIS CORDOBA',
#        'UNIVERSIDAD DE LOS LLANOS', 'UNIVERSIDAD POPULAR DEL CESAR',
#        'UNIVERSIDAD-COLEGIO MAYOR DE CUNDINAMARCA',
#        'UNIVERSIDAD DEL PACIFICO', 'UNIVERSIDAD DE ANTIOQUIA',
#        'UNIVERSIDAD DEL ATLANTICO', 'UNIVERSIDAD DEL VALLE',
#        'UNIVERSIDAD INDUSTRIAL DE SANTANDER', 'UNIVERSIDAD DE CARTAGENA',
#        'UNIVERSIDAD DE NARIÑO', 'UNIVERSIDAD DEL TOLIMA',
#        'UNIVERSIDAD DEL QUINDIO',
#        'UNIVERSIDAD FRANCISCO DE PAULA SANTANDER',
#        'UNIVERSIDAD DE PAMPLONA',
# ...

# %%
filtro = data[data['INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)'].astype(str).str.contains('Lozano',case=False)]
filtro_sex = filtro[filtro['SEXO'].astype(str).str.contains('Masculino',case=False)]
filtro_sex.iloc[:, 12:]
# Out:
#        CÓDIGO SNIES DEL PROGRAMA  \
# 11174                       1143
# 11175                       1143
# 11178                       1144
# 11179                       1144
# 11182                       1146
# ...                          ...
# 11504                     109144
# 11507                     109189
# 11508                     109189
# 11511                     111210
# 11513                       1166
#
#                                       PROGRAMA ACADÉMICO  ID NIVEL ACADÉMICO  \
# 11174                                     DISEÑO GRAFICO                   1
# 11175                                     DISEÑO GRAFICO                   1
# 11178                                  DISE¿O INDUSTRIAL                   1
# 11179                                  DISE¿O INDUSTRIAL                   1
# 11182                                         PUBLICIDAD                   1
# ...                                                  ...                 ...
# ...

# %%
#universidades_seleccionados = ['UNIVERSIDAD DE LOS ANDES']
#programas_seleccionados = ['MAESTRÍA EN INGENIERÍA DE INFORMACIÓN','MAESTRIA EN INTELIGENCIA ANALITICA DE DATOS','MAESTRÍA EN INTELIGENCIA ANALÍTICA PARA LA TOMA DE DECISIONES']

#universidades_seleccionados = ['UNIVERSIDAD ESCUELA COLOMBIANA DE INGENIERIA JULIO GARAVITO','PONTIFICIA UNIVERSIDAD JAVERIANA','UNIVERSIDAD SERGIO ARBOLEDA','FUNDACION UNIVERSIDAD DE BOGOTA - JORGE TADEO LOZANO']
#programas_seleccionados = ['MAESTRÍA EN GESTIÓN DE INFORMACIÓN','MAESTRÍA EN CIENCIA DE DATOS','MAESTRÍA EN INTELIGENCIA ARTIFICIAL','MAESTRIA EN INTELIGENCIA ARTIFICIAL','MAESTRÍA EN INGENIERÍA Y ANALÍTICA DE DATOS']

#universidades_seleccionados = ['ICESI','UNIVERSIDAD EAFIT-']
#programas_seleccionados = ['MAESTRÍA EN CIENCIA DE DATOS','MAESTRÍA EN CIENCIAS DE LOS DATOS Y ANALÍTICA']

universidades_seleccionados = ['UNIVERSIDAD DE LOS ANDES','UNIVERSIDAD ESCUELA COLOMBIANA DE INGENIERIA JULIO GARAVITO','PONTIFICIA UNIVERSIDAD JAVERIANA','UNIVERSIDAD SERGIO ARBOLEDA','FUNDACION UNIVERSIDAD DE BOGOTA - JORGE TADEO LOZANO','ICESI','UNIVERSIDAD EAFIT-']
programas_seleccionados = ['MAESTRÍA EN INGENIERÍA DE INFORMACIÓN','MAESTRIA EN INTELIGENCIA ANALITICA DE DATOS','MAESTRÍA EN INTELIGENCIA ANALÍTICA PARA LA TOMA DE DECISIONES','MAESTRÍA EN GESTIÓN DE INFORMACIÓN','MAESTRÍA EN CIENCIA DE DATOS','MAESTRÍA EN INTELIGENCIA ARTIFICIAL','MAESTRIA EN INTELIGENCIA ARTIFICIAL','MAESTRÍA EN INGENIERÍA Y ANALÍTICA DE DATOS','MAESTRÍA EN CIENCIA DE DATOS','MAESTRÍA EN CIENCIAS DE LOS DATOS Y ANALÍTICA']

institucion = data[data['INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)'].astype(str).str.contains('|'.join(universidades_seleccionados), case=False)]
programa = institucion[institucion['PROGRAMA ACADÉMICO'].astype(str).str.contains('|'.join(programas_seleccionados), case=False)]
print(programa)
#genero = programa[programa['SEXO'].astype(str).str.contains('Femenino', case=False)]
#print(genero)
# Out:
#        CÓDIGO DE LA INSTITUCIÓN  IES_PADRE  \
# 9058                       1701       1701
# 9059                       1701       1701
# 9060                       1701       1701
# 9061                       1701       1701
# 9375                       1702       1701
# 9376                       1702       1701
# 9377                       1702       1701
# 9378                       1702       1701
# 11425                      1707       1707
# 11426                      1707       1707
# 11427                      1707       1707
# 11428                      1707       1707
# 12949                      1712       1712
# 12950                      1712       1712
# 12951                      1712       1712
# 12952                      1712       1712
# 15854                      1728       1728
# 15855                      1728       1728
# 15856                      1728       1728
# 15857                      1728       1728
# 19281                      1813       1813
# ...

# %%
revision_programa = programa['PROGRAMA ACADÉMICO'].unique()
revision_programa
# Out:
# array(['MAESTRÍA EN INTELIGENCIA ARTIFICIAL',
#        'MAESTRÍA EN CIENCIA DE DATOS',
#        'MAESTRÍA EN INGENIERÍA Y ANALÍTICA DE DATOS',
#        'MAESTRÍA EN CIENCIAS DE LOS DATOS Y ANALÍTICA',
#        'MAESTRIA EN INTELIGENCIA ARTIFICIAL',
#        'MAESTRÍA EN INTELIGENCIA ANALÍTICA PARA LA TOMA DE DECISIONES',
#        'MAESTRÍA EN INGENIERÍA DE INFORMACIÓN',
#        'MAESTRIA EN INTELIGENCIA ANALITICA DE DATOS',
#        'MAESTRÍA EN GESTIÓN DE INFORMACIÓN'], dtype=object)

# %%
categorias_programa = programa['INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)'].unique()
categorias_programa
# Out:
# array(['PONTIFICIA UNIVERSIDAD JAVERIANA',
#        'FUNDACION UNIVERSIDAD DE BOGOTA - JORGE TADEO LOZANO',
#        'UNIVERSIDAD EAFIT-', 'UNIVERSIDAD SERGIO ARBOLEDA',
#        'UNIVERSIDAD DE LOS ANDES', 'UNIVERSIDAD ICESI',
#        'UNIVERSIDAD ESCUELA COLOMBIANA DE INGENIERIA JULIO GARAVITO'],
#       dtype=object)

# %%
cantidad_categorias = len(categorias_sector_ies)
cantidad_categorias
# Out:
# 274

# %%
import matplotlib.pyplot as plt
programa['INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)'].value_counts().plot(kind='bar')

# Configurar etiquetas y título
plt.xlabel('Universidades')
plt.ylabel('Número de Matriculados')
plt.title('Distribución de estudiantes')

# Mostrar el gráfico
plt.show()

# %%
#perfilamiento=ydata_profiling.ProfileReport(programa, minimal=True, explorative=True)
#perfilamiento

# %%
df = pd.DataFrame(programa)
df
# Out:
#        CÓDIGO DE LA INSTITUCIÓN  IES_PADRE  \
# 9058                       1701       1701
# 9059                       1701       1701
# 9060                       1701       1701
# 9061                       1701       1701
# 9375                       1702       1701
# 9376                       1702       1701
# 9377                       1702       1701
# 9378                       1702       1701
# 11425                      1707       1707
# 11426                      1707       1707
# 11427                      1707       1707
# 11428                      1707       1707
# 12949                      1712       1712
# 12950                      1712       1712
# 12951                      1712       1712
# 12952                      1712       1712
# 15854                      1728       1728
# 15855                      1728       1728
# 15856                      1728       1728
# 15857                      1728       1728
# 19281                      1813       1813
# ...

# %%
# Graficar un scatter plot con Plotly Express
fig = px.bar(df['INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)'].value_counts(),
             x=df['INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)'].value_counts().index,
             y=df['INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)'].value_counts().values,
             labels={'x': 'Universidades', 'y': 'Número de Matriculados'},
             title='Frecuencia de Universidades')

fig.update_xaxes(categoryorder='total descending', tickangle=20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df['PROGRAMA ACADÉMICO'].value_counts(),
             x=df['PROGRAMA ACADÉMICO'].value_counts().index,
             y=df['PROGRAMA ACADÉMICO'].value_counts().values,
             labels={'x': 'Programas', 'y': 'Número de Matriculados'},
             title='Frecuencia de Programas')

fig.update_xaxes(categoryorder='total descending', tickangle=20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
